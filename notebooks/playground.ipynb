# %% [markdown]
# # Notebook Session Labs — Playground
#
# This notebook is a **playground for testing and development** of the Notebook Session Labs MCP server (v0.2.0).
#
# It contains various cell types and scenarios to exercise the MCP bridge capabilities.

# %%
# Cell 0: Basic Python — simple expression
print("Hello from Notebook Session Labs!")
2 + 2
# Out:
# Hello from Notebook Session Labs!
# 4

# %%
# Cell 1: Variables and data
import sys
import platform

info = {
    "python": sys.version,
    "platform": platform.platform(),
    "implementation": platform.python_implementation(),
}

for key, value in info.items():
    print(f"{key}: {value}")
# Out:
# python: 3.12.3 (main, Mar 23 2026, 19:04:32) [GCC 13.3.0]
# platform: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.39
# implementation: CPython

# %% [markdown]
# ## Error Handling Test
#
# The cell below is intentionally broken to test error output handling.

# %%
# Cell 3: Intentional error — test error output capture
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Cell 3: Intentional error — test error output capture
# ----> 2 1 / 0
#
# ZeroDivisionError: division by zero

# %%
# Cell 4: Rich output — JSON structure
import json

data = {
    "name": "notebook-session-labs",
    "version": "0.2.0",
    "tools": [
        "get_active_notebook",
        "list_open_notebooks",
        "list_cells",
        "read_notebook",
        "read_cell",
        "read_cell_output",
        "get_selection",
        "insert_cell",
        "replace_cell",
        "edit_cell_source",
        "delete_cell",
        "move_cell",
        "execute_cell",
        "run_all_cells",
        "cancel_execution",
        "save_notebook",
    ],
}

print(json.dumps(data, indent=2))

# %%
# Cell 5: Long-running cell — test cancel_execution
import time

for i in range(60):
    print(f"Tick {i}...")
    time.sleep(1)
